# %% [markdown]
# # Logistic Regression - Student Pass Prediction

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Create Dataset

# %%
data = pd.DataFrame({
    'Hours':[2,3,5,6,8,1,4,7],
    'Attendance':[50,60,70,80,90,40,65,85],
    'Pass':[0,0,1,1,1,0,1,1]
})

print(data)
# Out:
#    Hours  Attendance  Pass
# 0      2          50     0
# 1      3          60     0
# 2      5          70     1
# 3      6          80     1
# 4      8          90     1
# 5      1          40     0
# 6      4          65     1
# 7      7          85     1

# %% [markdown]
# ## Split Features and Target

# %%
X = data[['Hours','Attendance']]
y = data['Pass']

# %% [markdown]
# ## Train Logistic Regression Model

# %%
model = LogisticRegression()
model.fit(X, y)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Predict Student Result

# %%
prediction = model.predict([[4,75]])

print("Prediction:", prediction[0])
# Out:
# Prediction: 1
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Visualize Classification Graph

# %%
fail = data[data['Pass'] == 0]
pass_ = data[data['Pass'] == 1]

plt.figure()

plt.scatter(fail['Hours'], fail['Attendance'], label="Fail")
plt.scatter(pass_['Hours'], pass_['Attendance'], label="Pass")

plt.title("Logistic Regression Classification")
plt.xlabel("Study Hours")
plt.ylabel("Attendance")

plt.legend()

plt.show()
