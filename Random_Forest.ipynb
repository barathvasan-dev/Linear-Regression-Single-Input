# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Create Dataset

# %%
data = pd.DataFrame({
    'Age':[22,25,30,35,40,45,50,28,32,38],
    'Income':[20000,30000,40000,50000,60000,70000,80000,35000,45000,55000],
    'SpendingScore':[30,40,50,60,70,80,85,45,55,65],
    'Buy':[0,0,1,1,1,1,0,1,1,1]
})

print(data)
# Out:
#    Age  Income  SpendingScore  Buy
# 0   22   20000             30    0
# 1   25   30000             40    0
# 2   30   40000             50    1
# 3   35   50000             60    1
# 4   40   60000             70    1
# 5   45   70000             80    1
# 6   50   80000             85    0
# 7   28   35000             45    1
# 8   32   45000             55    1
# 9   38   55000             65    1

# %% [markdown]
# ## Split Features and Target

# %%
X = data[['Age','Income','SpendingScore']]
y = data['Buy']

# %% [markdown]
# ## Train Random Forest Model

# %%
model = RandomForestClassifier()
model.fit(X, y)
# Out:
# RandomForestClassifier()

# %% [markdown]
# ## Predict Customer Purchase

# %%
prediction = model.predict([[28,35000,45]])

print("Prediction:", prediction[0])
# Out:
# Prediction: 1
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Visualize Feature Importance

# %%
importance = model.feature_importances_
features = X.columns

plt.figure()

plt.bar(features, importance)

plt.title("Feature Importance")
plt.xlabel("Features")
plt.ylabel("Importance")

plt.show()
